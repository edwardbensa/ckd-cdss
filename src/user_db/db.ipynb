# %%
patient = {
    "email_address": "",
    "postcode": "",
    "age": "",
    "gender": "",
    "height": "",
    "weight": "",
    "systolic": "",
    "diastolic": "",
    "hypertension": "",
    "family_hypertension": "",
    "diabetes": "",
    "family_diabetes": "",
    "glucose": "",

}
