# %%
import matplotlib
matplotlib.use("Agg")

# %%
"""Modular testing script for tabular data."""

# Imports
from src.tabular.utils.test_utils import evaluate_model


specs = {
    "model_dir": "/Users/Edward/DS/Projects/ckd-cdss/models/ucickd/bnn_20251221_181014",
    "test_file": "ucickd_test",
    "target": "ckd_status",
    "compute_shap": True
}

evaluate_model(specs)
# Out:
# 2025-12-23 09:45:49.601 | INFO     | src.tabular.utils.test_utils:evaluate_model:353 - Loaded test dataset with shape: (80, 25)
# 2025-12-23 09:45:49.608 | INFO     | src.tabular.utils.test_utils:evaluate_model:364 - Using selected features: ['bin__cad', 'num__hemo', 'bin__htn', 'num__d_bp', 'bin__appet_poor', 'num__sg', 'num__pcv', 'num__age', 'bin__dm']
# 2025-12-23 09:45:49.609 | INFO     | src.tabular.utils.test_utils:evaluate_model:378 - Detected BNN model - computing predictions with uncertainty...
# 2025-12-23 09:45:49.621 | INFO     | src.tabular.utils.test_utils:evaluate_model:394 - Mean uncertainty: 0.0073 (std: 0.0321)
# 2025-12-23 09:45:49.622 | INFO     | src.tabular.utils.test_utils:evaluate_model:395 - Max uncertainty: 0.2359, Min: 0.0000
# 2025-12-23 09:45:49.641 | INFO     | src.tabular.utils.test_utils:evaluate_model:407 - Test Accuracy: 1.0000
# 2025-12-23 09:45:49.641 | INFO     | src.tabular.utils.test_utils:evaluate_model:408 - Test ROC-AUC: 1.0000
# ...
