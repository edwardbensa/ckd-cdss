# %%
"""Modular testing script for tabular data."""

# Imports
from src.tabular.utils.test_utils import evaluate_model


specs = {
    "model_key": "bnn",
    "model_dir": "/Users/Edward/DS/Projects/ckd-cdss/models/ucickd/xgb_20251218_203800",
    "test_file": "ucickd_test",
    "target": "ckd_status",
}

evaluate_model(specs)
# Out:
# 2025-12-18 20:44:12.039 | INFO     | src.tabular.utils.test_utils:evaluate_model:40 - Loaded test dataset with shape: (80, 25)
# 2025-12-18 20:44:12.076 | INFO     | src.tabular.utils.test_utils:evaluate_model:51 - Using selected features: ['bin__cad', 'num__hemo', 'bin__htn', 'num__bp', 'bin__appet_poor', 'num__sg', 'num__age', 'num__sc', 'num__al']
# 2025-12-18 20:44:12.076 | INFO     | src.tabular.utils.test_utils:evaluate_model:57 - Evaluating model on test set...
# 2025-12-18 20:44:12.078 | INFO     | src.tabular.utils.test_utils:evaluate_model:64 - Test Accuracy: 0.9625
# 2025-12-18 20:44:12.078 | INFO     | src.tabular.utils.test_utils:evaluate_model:65 - Test ROC-AUC: 1.0000
# 2025-12-18 20:44:12.079 | INFO     | src.tabular.utils.test_utils:evaluate_model:71 - Saved classification report.
# 2025-12-18 20:44:12.170 | SUCCESS  | src.tabular.utils.test_utils:evaluate_model:113 - Testing complete. Results saved to model_dir.
